# %%
import numpy as np

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X = iris.data          # features
X.shape
# Out:
# (150, 4)

# %%
def expand_cluster(y,labels,i,neighbour,cluster_id,point_idx,eps,min_pts):
    labels[point_idx]=cluster_id
    i = 0
    while i<len(neighbour):
        neighbour_idx = neighbour[i]

# %% [markdown]
# If neighbour was noise, make it border points

# %%
# Out:
#   Cell In[7], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
x = np.array([1,2], [2,2], [2,2], )
